# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_excel('Cleaned_Dataset.xlsx')

# %%
df.head()
# Out:
#      OrderID       Date CustomerID  Product  Quantity  UnitPrice  \
# 0  ORD200000 2023-01-04     C72649  Monitor         5     570.62
# 1  ORD200001 2024-08-23     C75739    Phone         2     151.35
# 2  ORD200002 2024-02-27     C81728   Tablet         5     550.68
# 3  ORD200003 2023-10-15     C33540    Chair         1     273.19
# 4  ORD200004 2025-05-08     C81840  Printer         4     626.01
#
#   ShippingAddress PaymentMethod OrderStatus TrackingNumber  ItemsInCart  \
# 0     928 Main St    Debit Card     Shipped    TRK37947903            7
# 1     823 Main St        Online     Shipped    TRK91186779            3
# 2     512 Main St   Credit Card   Cancelled    TRK42903982            8
# 3     275 Main St    Debit Card    Returned    TRK62788070            5
# 4     668 Main St        Online   Delivered    TRK29241424            8
#
#   CouponCode ReferralSource  TotalPrice
# 0     SAVE10      Instagram     2853.10
# 1     SAVE10       Referral      302.70
# ...

# %%
df.shape
# Out:
# (1200, 14)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1200 entries, 0 to 1199
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   OrderID          1200 non-null   str
#  1   Date             1200 non-null   datetime64[us]
#  2   CustomerID       1200 non-null   str
#  3   Product          1200 non-null   str
#  4   Quantity         1200 non-null   int64
#  5   UnitPrice        1200 non-null   float64
#  6   ShippingAddress  1200 non-null   str
#  7   PaymentMethod    1200 non-null   str
#  8   OrderStatus      1200 non-null   str
#  9   TrackingNumber   1200 non-null   str
#  10  ItemsInCart      1200 non-null   int64
#  11  CouponCode       1200 non-null   str
#  12  ReferralSource   1200 non-null   str
#  13  TotalPrice       1200 non-null   float64
# dtypes: datetime64[us](1), float64(2), int64(2), str(9)
# memory usage: 131.4 KB

# %%
df.tail()
# Out:
#         OrderID       Date CustomerID  Product  Quantity  UnitPrice  \
# 1195  ORD201195 2024-06-20     C21126     Desk         1     107.04
# 1196  ORD201196 2024-03-04     C20095  Monitor         2     662.53
# 1197  ORD201197 2023-07-13     C79674   Tablet         2     436.84
# 1198  ORD201198 2024-08-22     C64753    Chair         4     262.52
# 1199  ORD201199 2023-06-11     C57502   Tablet         4     560.58
#
#      ShippingAddress PaymentMethod OrderStatus TrackingNumber  ItemsInCart  \
# 1195     392 Main St   Credit Card   Cancelled    TRK38009181            6
# 1196     778 Main St        Online   Cancelled    TRK69207593            5
# 1197     275 Main St        Online   Delivered    TRK88039356            2
# 1198     509 Main St    Debit Card   Cancelled    TRK71683331            4
# 1199     201 Main St     Gift Card    Returned    TRK51116746            6
#
#      CouponCode ReferralSource  TotalPrice
# 1195   FREESHIP         Google      107.04
# ...

# %%
df.columns
# Out:
# Index(['OrderID', 'Date', 'CustomerID', 'Product', 'Quantity', 'UnitPrice',
#        'ShippingAddress', 'PaymentMethod', 'OrderStatus', 'TrackingNumber',
#        'ItemsInCart', 'CouponCode', 'ReferralSource', 'TotalPrice'],
#       dtype='str')

# %%
df.describe()
# Out:
#                       Date     Quantity    UnitPrice  ItemsInCart   TotalPrice
# count                 1200  1200.000000  1200.000000  1200.000000  1200.000000
# mean   2024-03-22 16:58:48     2.945833   356.412750     5.485000  1053.968300
# min    2023-01-01 00:00:00     1.000000    11.390000     1.000000    11.390000
# 25%    2023-08-03 18:00:00     2.000000   186.062500     4.000000   410.520000
# 50%    2024-03-23 00:00:00     3.000000   364.210000     5.000000   823.615000
# 75%    2024-11-08 12:00:00     4.000000   521.570000     7.000000  1578.475000
# max    2025-06-30 00:00:00     5.000000   699.930000    10.000000  3456.400000
# std                    NaN     1.407557   197.177146     2.281983   819.856558

# %%
df.isnull().sum()
# Out:
# OrderID            0
# Date               0
# CustomerID         0
# Product            0
# Quantity           0
# UnitPrice          0
# ShippingAddress    0
# PaymentMethod      0
# OrderStatus        0
# TrackingNumber     0
# ItemsInCart        0
# CouponCode         0
# ReferralSource     0
# TotalPrice         0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.nunique()
# Out:
# OrderID            1200
# Date                671
# CustomerID         1189
# Product               7
# Quantity              5
# UnitPrice          1193
# ShippingAddress     655
# PaymentMethod         5
# OrderStatus           5
# TrackingNumber     1200
# ItemsInCart          10
# CouponCode            4
# ReferralSource        5
# TotalPrice         1195
# dtype: int64

# %%
df.dtypes
# Out:
# OrderID                       str
# Date               datetime64[us]
# CustomerID                    str
# Product                       str
# Quantity                    int64
# UnitPrice                 float64
# ShippingAddress               str
# PaymentMethod                 str
# OrderStatus                   str
# TrackingNumber                str
# ItemsInCart                 int64
# CouponCode                    str
# ReferralSource                str
# TotalPrice                float64
# dtype: object

# %%
import os
print(os.getcwd())
# Out:
# d:\Projects\DecodeLab-DataAnalytics\Project 2 Week

# %%
print(os.listdir())
# Out:
# ['Cleaned_Dataset.xlsx', 'eda.ipynb', 'images', 'README.md', 'requirements.txt']

# %%
import os

print(os.path.exists("Cleaned_Dataset.xlsx"))
# Out:
# True

# %%
df.drop_duplicates(inplace=True)

# %%
df.isnull().sum()
# Out:
# OrderID            0
# Date               0
# CustomerID         0
# Product            0
# Quantity           0
# UnitPrice          0
# ShippingAddress    0
# PaymentMethod      0
# OrderStatus        0
# TrackingNumber     0
# ItemsInCart        0
# CouponCode         0
# ReferralSource     0
# TotalPrice         0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1200 entries, 0 to 1199
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   OrderID          1200 non-null   str
#  1   Date             1200 non-null   datetime64[us]
#  2   CustomerID       1200 non-null   str
#  3   Product          1200 non-null   str
#  4   Quantity         1200 non-null   int64
#  5   UnitPrice        1200 non-null   float64
#  6   ShippingAddress  1200 non-null   str
#  7   PaymentMethod    1200 non-null   str
#  8   OrderStatus      1200 non-null   str
#  9   TrackingNumber   1200 non-null   str
#  10  ItemsInCart      1200 non-null   int64
#  11  CouponCode       1200 non-null   str
#  12  ReferralSource   1200 non-null   str
#  13  TotalPrice       1200 non-null   float64
# dtypes: datetime64[us](1), float64(2), int64(2), str(9)
# memory usage: 131.4 KB

# %%
df.to_excel("Cleaned_Dataset.xlsx", index=False)

# %%
df["Product"].value_counts()
# Out:
# Product
# Printer    181
# Tablet     179
# Chair      178
# Laptop     173
# Desk       170
# Monitor    163
# Phone      156
# Name: count, dtype: int64

# %%
df["PaymentMethod"].value_counts()
# Out:
# PaymentMethod
# Online         258
# Cash           246
# Credit Card    234
# Debit Card     232
# Gift Card      230
# Name: count, dtype: int64

# %%
df["OrderStatus"].value_counts()
# Out:
# OrderStatus
# Cancelled    250
# Returned     247
# Pending      237
# Shipped      235
# Delivered    231
# Name: count, dtype: int64

# %%
df["ReferralSource"].value_counts()
# Out:
# ReferralSource
# Instagram    259
# Email        250
# Google       241
# Facebook     228
# Referral     222
# Name: count, dtype: int64

# %%
df["TotalPrice"].mean()
# Out:
# np.float64(1053.9683)

# %%
df["TotalPrice"].max()
# Out:
# np.float64(3456.4)

# %%
df["TotalPrice"].min()
# Out:
# np.float64(11.39)

# %%
df["TotalPrice"].sum()
# Out:
# np.float64(1264761.96)

# %%
df["Quantity"].mean()
# Out:
# np.float64(2.9458333333333333)

# %%
df["OrderID"].count()
# Out:
# np.int64(1200)

# %%
df["CustomerID"].nunique()
# Out:
# 1189

# %%
df.groupby("Product")["TotalPrice"].sum()
# Out:
# Product
# Chair      195620.11
# Desk       167459.93
# Laptop     192126.56
# Monitor    175651.41
# Phone      151722.39
# Printer    195612.61
# Tablet     186568.95
# Name: TotalPrice, dtype: float64

# %%
df.groupby("PaymentMethod")["TotalPrice"].sum()
# Out:
# PaymentMethod
# Cash           259786.29
# Credit Card    263847.63
# Debit Card     232361.18
# Gift Card      246323.92
# Online         262442.94
# Name: TotalPrice, dtype: float64

# %%
df.groupby(df["Date"].dt.to_period("M"))["TotalPrice"].sum()
# Out:
# Date
# 2023-01    56685.75
# 2023-02    40117.66
# 2023-03    48609.37
# 2023-04    27751.71
# 2023-05    63836.84
# 2023-06    49500.19
# 2023-07    42820.66
# 2023-08    54352.14
# 2023-09    29526.67
# 2023-10    52607.85
# 2023-11    43079.67
# 2023-12    43754.73
# 2024-01    38528.08
# 2024-02    36909.57
# 2024-03    36030.90
# 2024-04    49613.14
# 2024-05    27909.11
# 2024-06    68068.54
# 2024-07    42963.98
# 2024-08    31991.07
# 2024-09    39794.98
# 2024-10    37226.97
# 2024-11    32413.76
# 2024-12    38785.77
# 2025-01    29099.40
# 2025-02    35317.55
# 2025-03    39200.66
# 2025-04    31821.20
# 2025-05    43396.64
# 2025-06    53047.40
# Freq: M, Name: TotalPrice, dtype: float64

# %%
df.nlargest(5, "TotalPrice")
# Out:
#         OrderID       Date CustomerID  Product  Quantity  UnitPrice  \
# 789   ORD200789 2023-08-17     C57276   Tablet         5     691.28
# 1122  ORD201122 2023-06-07     C38840  Monitor         5     678.19
# 632   ORD200632 2023-05-02     C67260   Laptop         5     678.16
# 469   ORD200469 2023-11-26     C13877    Chair         5     676.98
# 328   ORD200328 2023-02-28     C18404   Tablet         5     674.04
#
#      ShippingAddress PaymentMethod OrderStatus TrackingNumber  ItemsInCart  \
# 789      183 Main St        Online   Delivered    TRK75899752           10
# 1122     766 Main St        Online    Returned    TRK32496970            8
# 632      463 Main St     Gift Card   Delivered    TRK38229104            7
# 469      893 Main St          Cash   Cancelled    TRK17254691            5
# 328      546 Main St        Online   Cancelled    TRK89401624            7
#
#      CouponCode ReferralSource  TotalPrice
# 789      SAVE10          Email     3456.40
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_excel("Cleaned_Dataset.xlsx")
df["Product"].value_counts().plot(kind="bar", figsize=(8,5))
plt.title("Product Sales")
plt.xlabel("Product")
plt.ylabel("Orders")
plt.show()

# %%
df["PaymentMethod"].value_counts().plot(
    kind="pie",
    autopct="%1.1f%%",
    figsize=(6,6)
)

plt.title("Payment Method Distribution")
plt.ylabel("")
plt.show()

# %%
df["TotalPrice"].plot(
    kind="hist",
    bins=20,
    figsize=(8,5)
)

plt.title("Distribution of Total Price")
plt.xlabel("Total Price")
plt.ylabel("Frequency")
plt.show()

# %%
monthly_sales = df.groupby(df["Date"].dt.to_period("M"))["TotalPrice"].sum()

monthly_sales.plot(
    kind="line",
    figsize=(10,5),
    marker="o"
)

plt.title("Monthly Revenue")
plt.xlabel("Month")
plt.ylabel("Revenue")
plt.show()

# %%
plt.figure(figsize=(8,5))

plt.scatter(df["Quantity"], df["TotalPrice"])

plt.title("Quantity vs Total Price")
plt.xlabel("Quantity")
plt.ylabel("Total Price")

plt.show()

# %%
plt.figure(figsize=(6,5))

plt.boxplot(df["TotalPrice"])

plt.title("Total Price Distribution")

plt.show()

# %% [markdown]
# ### Most Ordered Product
# - The most ordered product is ________.
# - This product has the highest customer demand.
# ### Payment Method
# - The most preferred payment method is ________.
# ### Order Status
# - Most orders are ________.
# - This indicates the overall order fulfillment performance.
# ### Referral Source
# - Most customers came through ________.
# ### Revenue
# - Total revenue generated: ₹________.
# ### Average Order Value
# - The average order value is ₹________.
# ### Highest Order
# - The highest order value is ₹________.
# ### Monthly Sales
# - Sales varied across different months.
# - The highest sales were recorded in ________.
# ### Product Revenue
# - The highest revenue was generated by ________.
# ### Customer Base
# - The dataset contains ________ unique customers.

# %% [markdown]
# # Conclusion
#
# This project analyzed an e-commerce dataset using Python and Pandas. The dataset was explored, cleaned, and analyzed to understand customer purchasing behavior, product performance, payment preferences, and sales trends. Various visualizations were created using Matplotlib to present the findings. The insights obtained from this analysis can help businesses improve inventory management, marketing strategies, and customer experience.

# %%
df["Product"].value_counts().plot(kind="bar", figsize=(8,5))
plt.title("Product Sales")
plt.xlabel("Product")
plt.ylabel("Orders")

plt.savefig("images/product_sales.png", dpi=300, bbox_inches="tight")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[49], line 6
#       2 plt.title("Product Sales")
#       3 plt.xlabel("Product")
#       4 plt.ylabel("Orders")
#       5
# ----> 6 plt.savefig("images/product_sales.png", dpi=300, bbox_inches="tight")
#       7 plt.show()
#
# File d:\Projects\DecodeLab-DataAnalytics\.venv\Lib\site-packages\matplotlib\pyplot.py:1346, in savefig(fname, **kwargs)
#    1343 fig = gcf()
#    1344 # savefig default implementation has no return, so mypy is unhappy
#    1345 # presumably this is here because subclasses can return?
# -> 1346 res = fig.savefig(fname, **kwargs)  # type: ignore[func-returns-value]
#    1347 fig.canvas.draw_idle()  # Need this if 'transparent=True', to reset colors.
#    1348 return res
#
# ...
